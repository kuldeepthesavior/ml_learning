# %%
# ! pip install pandas
# ! pip install numpy
# ! pip install matplotlib
# ! pip install seaborn
# ! pip install scikit-learn

# %%
from pathlib import Path

data_dir = Path('../../data/store-sales/store-sales-time-series-forecasting')

# %%
import pandas as pd
import os
df = pd.read_csv(os.path.join(data_dir,'oil.csv'))
df.shape
# Out:
# (1218, 2)

# %%
# ! pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ryanholbrook/ts-course-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/disha/.cache/kagglehub/datasets/ryanholbrook/ts-course-data/versions/14

# %%
for x, y, z in os.walk(path):
    print(x, y, z)
# Out:
# /home/disha/.cache/kagglehub/datasets/ryanholbrook/ts-course-data/versions/14 [] []

# %%
for x, y, z in os.walk(path):
    print(a)
    for a in z:
        print(a)
        shutil.move(os.path.join(path,a), os.path.join(Path('../../data/ts-course-data'), a))
# Out:
# flu-trends.csv
